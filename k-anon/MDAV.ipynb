# %%
# !pip install pyspark
# !apt install openjdk-8-jdk-headless -qq

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# Out:
# Collecting pyspark
#   Downloading https://files.pythonhosted.org/packages/45/b0/9d6860891ab14a39d4bddf80ba26ce51c2f9dc4805e5c6978ac0472c120a/pyspark-3.1.1.tar.gz (212.3MB)
#      |████████████████████████████████| 212.3MB 65kB/s
# Collecting py4j==0.10.9
#   Downloading https://files.pythonhosted.org/packages/9e/b6/6a4fb90cd235dc8e265a6a2067f2a2c99f0d91787f06aca4bcf7c23f3f80/py4j-0.10.9-py2.py3-none-any.whl (198kB)
#      |████████████████████████████████| 204kB 18.0MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.1.1-py2.py3-none-any.whl size=212767604 sha256=101ed974451c3f07a1c419328dd97bb438fee4db58aeb6f8eeae5f31c71f1f11
#   Stored in directory: /root/.cache/pip/wheels/0b/90/c0/01de724414ef122bd05f056541fb6a0ecf47c7ca655f8b3c0f
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9 pyspark-3.1.1
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   openjdk-8-jre-headless
# Suggested packages:
#   openjdk-8-demo openjdk-8-source libnss-mdns fonts-dejavu-extra
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   openjdk-8-jdk-headless openjdk-8-jre-headless
# 0 upgraded, 2 newly installed, 0 to remove and 34 not upgraded.
# Need to get 36.5 MB of archives.
# After this operation, 143 MB of additional disk space will be used.
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# (Reading database ... 160706 files and directories currently installed.)
# Preparing to unpack .../openjdk-8-jre-headless_8u292-b10-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# Selecting previously unselected package openjdk-8-jdk-headless:amd64.
# Preparing to unpack .../openjdk-8-jdk-headless_8u292-b10-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jdk-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# Setting up openjdk-8-jre-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Setting up openjdk-8-jdk-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/idlj to provide /usr/bin/idlj (idlj) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsimport to provide /usr/bin/wsimport (wsimport) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jsadebugd to provide /usr/bin/jsadebugd (jsadebugd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/native2ascii to provide /usr/bin/native2ascii (native2ascii) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/javah to provide /usr/bin/javah (javah) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/hsdb to provide /usr/bin/hsdb (hsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/clhsdb to provide /usr/bin/clhsdb (clhsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/extcheck to provide /usr/bin/extcheck (extcheck) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/schemagen to provide /usr/bin/schemagen (schemagen) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/xjc to provide /usr/bin/xjc (xjc) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jhat to provide /usr/bin/jhat (jhat) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsgen to provide /usr/bin/wsgen (wsgen) in auto mode

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.decomposition import SparsePCA

import scipy.sparse as sparse

import pyspark
from pyspark.sql import *
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark import SparkContext, SparkConf
from pyspark.mllib.linalg.distributed import RowMatrix
from pyspark.mllib.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StandardScaler

from datetime import datetime
import os

# %%
# create the session
conf = SparkConf().set("spark.ui.port", "4050")

# create the context
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession.builder.getOrCreate()

# %%
from google.colab import drive
drive.mount("/content/drive",force_remount=True)
# Out:
# Mounted at /content/drive

# %%
EUCLIDEAN_DISTANCE = 1
MANHATTAN_DISTANCE = 2

# %%
dateparse = lambda x: datetime.utcfromtimestamp(int(x)).strftime('%Y-%m-%d %H:%M:%S')

files_path = '/content/drive/MyDrive/CSE547_Final_Project/ml-100k'
ratings_file = os.path.join(files_path, "ratings.csv")
movies_file = os.path.join(files_path, "movies.csv")
user_movie_ratings_matrix = os.path.join(files_path, "user_movie_ratings_matrix.csv")

ratings_df = pd.read_csv(   ratings_file, 
                            parse_dates=['timestamp'], 
                            date_parser=dateparse)
movies_df = pd.read_csv(movies_file)

# %%
user_movie_ratings_df = spark.read.csv(user_movie_ratings_matrix, header=True, inferSchema=True)

# %%
feature_columns = user_movie_ratings_df.columns
feature_columns.remove('userId')
vector_assembler = VectorAssembler(inputCols = feature_columns, outputCol = 'features_sparse')
user_movie_ratings_features_df = vector_assembler.transform(user_movie_ratings_df).select(['userId', 'features_sparse'])

# %%
standardizer = StandardScaler(withMean=True, withStd=True, inputCol='features_sparse', outputCol='features')
standardizer_model = standardizer.fit(user_movie_ratings_features_df)
user_movie_ratings_standardized_features_df = standardizer_model.transform(user_movie_ratings_features_df)
scaled_features_rows_rdd = user_movie_ratings_standardized_features_df.select("features").rdd
features_rows_rdd = user_movie_ratings_standardized_features_df.select("features_sparse").rdd

# %%
scaled_features_rows_rdd = scaled_features_rows_rdd.zipWithIndex()
scaled_features_rows_rdd = scaled_features_rows_rdd.map(lambda x: (x[1], np.array(x[0])) )

# %%
features_rows_rdd = features_rows_rdd.zipWithIndex()
features_rows_rdd = features_rows_rdd.map(lambda x: (x[1], np.array(x[0])) )

# %%
def euclidean_distance(point1, point2):
    return np.linalg.norm(point1 - point2) ** 2

# %%
def manhattan_distance(point1, point2):
    return abs(point1 - point2).sum()

# %%
def get_distance(point, centroid, distance_measure = EUCLIDEAN_DISTANCE):

    point_info = ()

    if distance_measure == EUCLIDEAN_DISTANCE:
        point_info = (point, euclidean_distance(point, centroid)) # value
    elif distance_measure == MANHATTAN_DISTANCE:
        point_info = (point, manhattan_distance(point, centroid)) # value
    else:
        raise NotImplementedError(f'{distance_measure} is not implemented.')

    return point_info

# %%
def get_centroid(data_rdd, distance_measure = EUCLIDEAN_DISTANCE):
    num_points = data_rdd.count()
    
    center_point = data_rdd.values().sum() / num_points

    # distances = (index, (point, distance))
    distances = data_rdd.map(lambda p: (p[0], get_distance(p[1], center_point, distance_measure)) )
    centroid = distances.takeOrdered(1, lambda x: x[1][1])[0][1][0]
    # centroid = distances.sortBy(lambda x: x[1][1]).collect()[0][1][0]

    return np.array(centroid)

# %%
def get_farthest_from_centroid(data_rdd, centroid, distance_measure = EUCLIDEAN_DISTANCE):
    # distances = (index, (point, distance))
    distances = data_rdd.map(lambda p: (p[0], get_distance(p[1], centroid, distance_measure)) )
    farthest_point = distances.takeOrdered(1, lambda x: -x[1][1])[0][1][0]
    # farthest_point = distances.sortBy(lambda x: x[1][1]).collect()[-1][1][0]

    return np.array(farthest_point)

# %%
def microaggregate(points_list, method = 'avg'):
    k = len(points_list)
    
    if method == 'avg':
        microaggregated = np.sum(points_list, axis=0) / k
    else:
        raise NotImplementedError(f'{method} is not implemented.')
    
    return microaggregated

# %%
def group_k_points(data_rdd, center, k, method = 'avg', distance_measure = EUCLIDEAN_DISTANCE):

    distances = data_rdd.map(lambda p: (p[0], get_distance(p[1], center, distance_measure)) )
    k_closest = distances.takeOrdered(k, lambda x: x[1][1])
    k_closest = [(x[0], x[1][0]) for x in k_closest]

    microaggregated = microaggregate([(x[1]) for x in k_closest], method)

    return microaggregated, k_closest

# %%
def MDAV(data_rdd, k = 5, distance_measure = EUCLIDEAN_DISTANCE, method = 'avg'):
    num_total_points = data_rdd.count()
    num_points = num_total_points

    num_features = data_rdd.top(1)[0][1].shape
    anonymized = np.zeros(num_features)
    while num_points >= 2*k:
        C = get_centroid(data_rdd, distance_measure)
        P = get_farthest_from_centroid(data_rdd, C, distance_measure)
        Q = get_farthest_from_centroid(data_rdd, P, distance_measure)
        
        for k_anon_center in [P, Q]:
            microaggregated, grouped = group_k_points(data_rdd, k_anon_center, k, method, distance_measure)
            grouped_rdd = sc.parallelize(grouped)
            # print(f'\tGrouped {grouped_rdd.keys().collect()}')

            # Add the anonymized group to an array
            anonymized = np.vstack([anonymized, microaggregated])

            # Remove the grouped points from the main datapoints
            data_rdd = data_rdd.subtractByKey(grouped_rdd)
        
        num_points = data_rdd.count()
        print(f'Number of points remaining: {num_points} / {num_total_points}')
        # print()
    
    if k < num_points < (2*k - 1):
        remain = data_rdd.map(lambda p: p[1]).collect()
        microaggregated = microaggregate(remain, method)
        
        # Add the anonymized group to an array
        anonymized = np.vstack([anonymized, microaggregated])
    else:
        # We should force these into points into the previous microcell
        # However, these may corrupt the data. Therefore, we ignore these points
        pass
    
    anonymized = np.delete(anonymized, 0, axis=0)
    return anonymized

# %%
distance_measure = EUCLIDEAN_DISTANCE
method = 'avg'
scaled = False

ratings_data_rdd = features_rows_rdd
if scaled:
    ratings_data_rdd = scaled_features_rows_rdd

k_values = [2, 3, 5, 8, 12, 15, 20, 25]
for k in k_values:
    anonymized = MDAV(ratings_data_rdd, k, distance_measure, method)

    anon_file_name = f'{k}_anonymized'
    if scaled: anon_file_name += '_scaled'
    anon_file_name += '.csv'

    anon_file_path = os.path.join(files_path, anon_file_name)
    np.savetxt(anon_file_path, anonymized, delimiter=",")

    print(f'Done with k = {k}')
# Out:
# Number of points remaining: 606 / 610
# Number of points remaining: 602 / 610
# Number of points remaining: 598 / 610
# Number of points remaining: 594 / 610
# Number of points remaining: 590 / 610
# Number of points remaining: 586 / 610
# Number of points remaining: 582 / 610
# Number of points remaining: 578 / 610
# Number of points remaining: 574 / 610
# Number of points remaining: 570 / 610
# Number of points remaining: 566 / 610
# Number of points remaining: 562 / 610
# Number of points remaining: 558 / 610
# Number of points remaining: 554 / 610
# Number of points remaining: 550 / 610
# Number of points remaining: 546 / 610
# Number of points remaining: 542 / 610
# Number of points remaining: 538 / 610
# Number of points remaining: 534 / 610
# Number of points remaining: 530 / 610
# Number of points remaining: 526 / 610
# Number of points remaining: 522 / 610
# Number of points remaining: 518 / 610
# Number of points remaining: 514 / 610
# Number of points remaining: 510 / 610
# Number of points remaining: 506 / 610
# Number of points remaining: 502 / 610
# Number of points remaining: 498 / 610
# Number of points remaining: 494 / 610
# Number of points remaining: 490 / 610
# Number of points remaining: 486 / 610
# Number of points remaining: 482 / 610
# Number of points remaining: 478 / 610
# Number of points remaining: 474 / 610
# Number of points remaining: 470 / 610
# Number of points remaining: 466 / 610
# Number of points remaining: 462 / 610
# Number of points remaining: 458 / 610
# Number of points remaining: 454 / 610
# Number of points remaining: 450 / 610
# Number of points remaining: 446 / 610
# Number of points remaining: 442 / 610
# Number of points remaining: 438 / 610
# Number of points remaining: 434 / 610
# Number of points remaining: 430 / 610
# Number of points remaining: 426 / 610
# Number of points remaining: 422 / 610
# Number of points remaining: 418 / 610
# Number of points remaining: 414 / 610
# Number of points remaining: 410 / 610
# Number of points remaining: 406 / 610
# Number of points remaining: 402 / 610
# Number of points remaining: 398 / 610
# Number of points remaining: 394 / 610
# Number of points remaining: 390 / 610
# Number of points remaining: 386 / 610
# Number of points remaining: 382 / 610
# Number of points remaining: 378 / 610
# Number of points remaining: 374 / 610
# Number of points remaining: 370 / 610
# Number of points remaining: 366 / 610
# Number of points remaining: 362 / 610
# Number of points remaining: 358 / 610
# Number of points remaining: 354 / 610
# Number of points remaining: 350 / 610
# Number of points remaining: 346 / 610
# Number of points remaining: 342 / 610
# Number of points remaining: 338 / 610
# Number of points remaining: 334 / 610
# Number of points remaining: 330 / 610
# Number of points remaining: 326 / 610
# Number of points remaining: 322 / 610
# Number of points remaining: 318 / 610
# Number of points remaining: 314 / 610
# Number of points remaining: 310 / 610
# Number of points remaining: 306 / 610
# Number of points remaining: 302 / 610
# Number of points remaining: 298 / 610
# Number of points remaining: 294 / 610
# Number of points remaining: 290 / 610
# Number of points remaining: 286 / 610
# Number of points remaining: 282 / 610
# Number of points remaining: 278 / 610
# Number of points remaining: 274 / 610
# Number of points remaining: 270 / 610
# Number of points remaining: 266 / 610
# Number of points remaining: 262 / 610
# Number of points remaining: 258 / 610
# Number of points remaining: 254 / 610
# Number of points remaining: 250 / 610
# Number of points remaining: 246 / 610
# Number of points remaining: 242 / 610
# Number of points remaining: 238 / 610
# Number of points remaining: 234 / 610
# Number of points remaining: 230 / 610
# Number of points remaining: 226 / 610
# Number of points remaining: 222 / 610
# Number of points remaining: 218 / 610
# Number of points remaining: 214 / 610
# Number of points remaining: 210 / 610
# Number of points remaining: 206 / 610
# Number of points remaining: 202 / 610
# Number of points remaining: 198 / 610
# Number of points remaining: 194 / 610
# Number of points remaining: 190 / 610
# Number of points remaining: 186 / 610
# Number of points remaining: 182 / 610
# Number of points remaining: 178 / 610
# Number of points remaining: 174 / 610
# Number of points remaining: 170 / 610
# Number of points remaining: 166 / 610
# Number of points remaining: 162 / 610
# Number of points remaining: 158 / 610
# Number of points remaining: 154 / 610
# Number of points remaining: 150 / 610
# Number of points remaining: 146 / 610
# Number of points remaining: 142 / 610
# Number of points remaining: 138 / 610
# Number of points remaining: 134 / 610
# Number of points remaining: 130 / 610
# Number of points remaining: 126 / 610
# Number of points remaining: 122 / 610
# Number of points remaining: 118 / 610
# Number of points remaining: 114 / 610
# Number of points remaining: 110 / 610
# Number of points remaining: 106 / 610
# Number of points remaining: 102 / 610
# Number of points remaining: 98 / 610
# Number of points remaining: 94 / 610
# Number of points remaining: 90 / 610
# Number of points remaining: 86 / 610
# Number of points remaining: 82 / 610
# Number of points remaining: 78 / 610
# Number of points remaining: 74 / 610
# Number of points remaining: 70 / 610
# Number of points remaining: 66 / 610
# Number of points remaining: 62 / 610
# Number of points remaining: 58 / 610
# Number of points remaining: 54 / 610
# Number of points remaining: 50 / 610
# Number of points remaining: 46 / 610
# Number of points remaining: 42 / 610
# Number of points remaining: 38 / 610
# Number of points remaining: 34 / 610
# Number of points remaining: 30 / 610
# Number of points remaining: 26 / 610
# Number of points remaining: 22 / 610
# Number of points remaining: 18 / 610
# Number of points remaining: 14 / 610
# Number of points remaining: 10 / 610
# Number of points remaining: 6 / 610
# Number of points remaining: 2 / 610
# Done with k = 2
# Number of points remaining: 604 / 610
# Number of points remaining: 598 / 610
# Number of points remaining: 592 / 610
# Number of points remaining: 586 / 610
# Number of points remaining: 580 / 610
# Number of points remaining: 574 / 610
# Number of points remaining: 568 / 610
# Number of points remaining: 562 / 610
# Number of points remaining: 556 / 610
# Number of points remaining: 550 / 610
# Number of points remaining: 544 / 610
# Number of points remaining: 538 / 610
# Number of points remaining: 532 / 610
# Number of points remaining: 526 / 610
# Number of points remaining: 520 / 610
# Number of points remaining: 514 / 610
# Number of points remaining: 508 / 610
# Number of points remaining: 502 / 610
# Number of points remaining: 496 / 610
# Number of points remaining: 490 / 610
# Number of points remaining: 484 / 610
# Number of points remaining: 478 / 610
# Number of points remaining: 472 / 610
# Number of points remaining: 466 / 610
# Number of points remaining: 460 / 610
# Number of points remaining: 454 / 610
# Number of points remaining: 448 / 610
# Number of points remaining: 442 / 610
# Number of points remaining: 436 / 610
# Number of points remaining: 430 / 610
# Number of points remaining: 424 / 610
# Number of points remaining: 418 / 610
# Number of points remaining: 412 / 610
# Number of points remaining: 406 / 610
# Number of points remaining: 400 / 610
# Number of points remaining: 394 / 610
# Number of points remaining: 388 / 610
# Number of points remaining: 382 / 610
# Number of points remaining: 376 / 610
# Number of points remaining: 370 / 610
# Number of points remaining: 364 / 610
# Number of points remaining: 358 / 610
# Number of points remaining: 352 / 610
# Number of points remaining: 346 / 610
# Number of points remaining: 340 / 610
# Number of points remaining: 334 / 610
# Number of points remaining: 328 / 610
# Number of points remaining: 322 / 610
# Number of points remaining: 316 / 610
# Number of points remaining: 310 / 610
# Number of points remaining: 304 / 610
# Number of points remaining: 298 / 610
# Number of points remaining: 292 / 610
# Number of points remaining: 286 / 610
# Number of points remaining: 280 / 610
# Number of points remaining: 274 / 610
# Number of points remaining: 268 / 610
# Number of points remaining: 262 / 610
# Number of points remaining: 256 / 610
# Number of points remaining: 250 / 610
# Number of points remaining: 244 / 610
# Number of points remaining: 238 / 610
# Number of points remaining: 232 / 610
# Number of points remaining: 226 / 610
# Number of points remaining: 220 / 610
# Number of points remaining: 214 / 610
# Number of points remaining: 208 / 610
# Number of points remaining: 202 / 610
# Number of points remaining: 196 / 610
# Number of points remaining: 190 / 610
# Number of points remaining: 184 / 610
# Number of points remaining: 178 / 610
# Number of points remaining: 172 / 610
# Number of points remaining: 166 / 610
# Number of points remaining: 160 / 610
# Number of points remaining: 154 / 610
# Number of points remaining: 148 / 610
# Number of points remaining: 142 / 610
# Number of points remaining: 136 / 610
# Number of points remaining: 130 / 610
# Number of points remaining: 124 / 610
# Number of points remaining: 118 / 610
# Number of points remaining: 112 / 610
# Number of points remaining: 106 / 610
# Number of points remaining: 100 / 610
# Number of points remaining: 94 / 610
# Number of points remaining: 88 / 610
# Number of points remaining: 82 / 610
# Number of points remaining: 76 / 610
# Number of points remaining: 70 / 610
# Number of points remaining: 64 / 610
# Number of points remaining: 58 / 610
# Number of points remaining: 52 / 610
# Number of points remaining: 46 / 610
# Number of points remaining: 40 / 610
# Number of points remaining: 34 / 610
# Number of points remaining: 28 / 610
# Number of points remaining: 22 / 610
# Number of points remaining: 16 / 610
# Number of points remaining: 10 / 610
# Number of points remaining: 4 / 610
# Done with k = 3
# Number of points remaining: 600 / 610
# Number of points remaining: 590 / 610
# Number of points remaining: 580 / 610
# Number of points remaining: 570 / 610
# Number of points remaining: 560 / 610
# Number of points remaining: 550 / 610
# Number of points remaining: 540 / 610
# Number of points remaining: 530 / 610
# Number of points remaining: 520 / 610
# Number of points remaining: 510 / 610
# Number of points remaining: 500 / 610
# Number of points remaining: 490 / 610
# Number of points remaining: 480 / 610
# Number of points remaining: 470 / 610
# Number of points remaining: 460 / 610
# Number of points remaining: 450 / 610
# Number of points remaining: 440 / 610
# Number of points remaining: 430 / 610
# Number of points remaining: 420 / 610
# Number of points remaining: 410 / 610
# Number of points remaining: 400 / 610
# Number of points remaining: 390 / 610
# Number of points remaining: 380 / 610
# Number of points remaining: 370 / 610
# Number of points remaining: 360 / 610
# Number of points remaining: 350 / 610
# Number of points remaining: 340 / 610
# Number of points remaining: 330 / 610
# Number of points remaining: 320 / 610
# Number of points remaining: 310 / 610
# Number of points remaining: 300 / 610
# Number of points remaining: 290 / 610
# Number of points remaining: 280 / 610
# Number of points remaining: 270 / 610
# Number of points remaining: 260 / 610
# Number of points remaining: 250 / 610
# Number of points remaining: 240 / 610
# Number of points remaining: 230 / 610
# Number of points remaining: 220 / 610
# Number of points remaining: 210 / 610
# Number of points remaining: 200 / 610
# Number of points remaining: 190 / 610
# Number of points remaining: 180 / 610
# Number of points remaining: 170 / 610
# Number of points remaining: 160 / 610
# Number of points remaining: 150 / 610
# Number of points remaining: 140 / 610
# Number of points remaining: 130 / 610
# Number of points remaining: 120 / 610
# Number of points remaining: 110 / 610
# Number of points remaining: 100 / 610
# Number of points remaining: 90 / 610
# Number of points remaining: 80 / 610
# Number of points remaining: 70 / 610
# Number of points remaining: 60 / 610
# Number of points remaining: 50 / 610
# Number of points remaining: 40 / 610
# Number of points remaining: 30 / 610
# Number of points remaining: 20 / 610
# Number of points remaining: 10 / 610
# Number of points remaining: 0 / 610
# Done with k = 5
# Number of points remaining: 594 / 610
# Number of points remaining: 578 / 610
# Number of points remaining: 562 / 610
# Number of points remaining: 546 / 610
# Number of points remaining: 530 / 610
# Number of points remaining: 514 / 610
# Number of points remaining: 498 / 610
# Number of points remaining: 482 / 610
# Number of points remaining: 466 / 610
# Number of points remaining: 450 / 610
# Number of points remaining: 434 / 610
# Number of points remaining: 418 / 610
# Number of points remaining: 402 / 610
# Number of points remaining: 386 / 610
# Number of points remaining: 370 / 610
# Number of points remaining: 354 / 610
# Number of points remaining: 338 / 610
# Number of points remaining: 322 / 610
# Number of points remaining: 306 / 610
# Number of points remaining: 290 / 610
# Number of points remaining: 274 / 610
# Number of points remaining: 258 / 610
# Number of points remaining: 242 / 610
# Number of points remaining: 226 / 610
# Number of points remaining: 210 / 610
# Number of points remaining: 194 / 610
# Number of points remaining: 178 / 610
# Number of points remaining: 162 / 610
# Number of points remaining: 146 / 610
# Number of points remaining: 130 / 610
# Number of points remaining: 114 / 610
# Number of points remaining: 98 / 610
# Number of points remaining: 82 / 610
# Number of points remaining: 66 / 610
# Number of points remaining: 50 / 610
# Number of points remaining: 34 / 610
# Number of points remaining: 18 / 610
# Number of points remaining: 2 / 610
# Done with k = 8
# Number of points remaining: 586 / 610
# Number of points remaining: 562 / 610
# Number of points remaining: 538 / 610
# Number of points remaining: 514 / 610
# Number of points remaining: 490 / 610
# Number of points remaining: 466 / 610
# Number of points remaining: 442 / 610
# Number of points remaining: 418 / 610
# Number of points remaining: 394 / 610
# Number of points remaining: 370 / 610
# Number of points remaining: 346 / 610
# Number of points remaining: 322 / 610
# Number of points remaining: 298 / 610
# Number of points remaining: 274 / 610
# Number of points remaining: 250 / 610
# Number of points remaining: 226 / 610
# Number of points remaining: 202 / 610
# Number of points remaining: 178 / 610
# Number of points remaining: 154 / 610
# Number of points remaining: 130 / 610
# Number of points remaining: 106 / 610
# Number of points remaining: 82 / 610
# Number of points remaining: 58 / 610
# Number of points remaining: 34 / 610
# Number of points remaining: 10 / 610
# Done with k = 12
# Number of points remaining: 580 / 610
# Number of points remaining: 550 / 610
# Number of points remaining: 520 / 610
# Number of points remaining: 490 / 610
# Number of points remaining: 460 / 610
# Number of points remaining: 430 / 610
# Number of points remaining: 400 / 610
# Number of points remaining: 370 / 610
# Number of points remaining: 340 / 610
# Number of points remaining: 310 / 610
# Number of points remaining: 280 / 610
# Number of points remaining: 250 / 610
# Number of points remaining: 220 / 610
# Number of points remaining: 190 / 610
# Number of points remaining: 160 / 610
# Number of points remaining: 130 / 610
# Number of points remaining: 100 / 610
# Number of points remaining: 70 / 610
# Number of points remaining: 40 / 610
# Number of points remaining: 10 / 610
# Done with k = 15
# Number of points remaining: 570 / 610
# Number of points remaining: 530 / 610
# Number of points remaining: 490 / 610
# Number of points remaining: 450 / 610
# Number of points remaining: 410 / 610
# Number of points remaining: 370 / 610
# Number of points remaining: 330 / 610
# Number of points remaining: 290 / 610
# Number of points remaining: 250 / 610
# Number of points remaining: 210 / 610
# Number of points remaining: 170 / 610
# Number of points remaining: 130 / 610
# Number of points remaining: 90 / 610
# Number of points remaining: 50 / 610
# Number of points remaining: 10 / 610
# Done with k = 20
# Number of points remaining: 560 / 610
# Number of points remaining: 510 / 610
# Number of points remaining: 460 / 610
# Number of points remaining: 410 / 610
# Number of points remaining: 360 / 610
# Number of points remaining: 310 / 610
# Number of points remaining: 260 / 610
# Number of points remaining: 210 / 610
# Number of points remaining: 160 / 610
# Number of points remaining: 110 / 610
# Number of points remaining: 60 / 610
# Number of points remaining: 10 / 610
# Done with k = 25
